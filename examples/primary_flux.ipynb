# %% [markdown]
# Dependence on primary cosmic ray flux
# -----------------------------------

# %%
#basic imports and ipython setup
# %load_ext autoreload
# %matplotlib inline
# %autoreload 2
import os
import matplotlib.pyplot as plt
import numpy as np
os.chdir('..')

#import solver related modules
from MCEq.core import MCEqRun
from mceq_config import config
#import primary model choices
import CRFluxModels as pm

# %% [markdown]
# Create an instance of an MCEqRun class. Most of its areguments are contained in the `config` dictionary from the `mceq_config` module. Look into or edit `mceq_config.py`.
#
# If the initialization succeeds it will print out some information according to the debug level.

# %%
mceq_run = MCEqRun(
#provide the string of the interaction model
interaction_model='SIBYLL2.3',
#primary cosmic ray flux model
#support a tuple (primary model class (not instance!), arguments)
primary_model=(pm.Thunman,None),#(pm.HillasGaisser2012, "H3a"),
# Zenith angle in degrees. 0=vertical, 90=horizontal
theta_deg=0.0,
#expand the rest of the options from mceq_config.py
**config
)
# Out:
# InteractionYields::_load(): entering..
# InteractionYields::_load(): Looking for /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/SIBYLL23_yields_compact_ledpm.bz2
# convert_to_compact(): Low energy extension requested /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/SIBYLL23_yields_compact_ledpm.bz2
# convert_to_compact(): Attempting conversion of /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/SIBYLL23_yields.bz2
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-10421] 0.0177311028403
# >  Recurse -3122 [-10421] -11 0.0177311028403
# >  Recurse -3122 [-10421] 11 0.0177311028403
# >  Recurse -3122 [-10421] 22 0.0177311028403
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4332] 2.86579032289e-05
# >  Recurse -3122 [-4332] -3322 2.86579032289e-05
# ------>  Recurse -3122 [-4332, -3322] -11 2.13963244653e-05
# ------>  Recurse -3122 [-4332, -3322] 11 2.13963244653e-05
# ------>  Recurse -3122 [-4332, -3322] 22 2.13963244653e-05
# >  Recurse -3122 [-4332] -3312 2.86579032289e-05
# ------>  Recurse -3122 [-4332, -3312] -3112 1.47222598106e-05
# ------------>  Recurse -3122 [-4332, -3312, -3112] -11 1.91304916772e-09
# ------>  Recurse -3122 [-4332, -3312] -11 1.47222598106e-05
# ------>  Recurse -3122 [-4332, -3312] 11 1.47222598106e-05
# ------>  Recurse -3122 [-4332, -3312] 22 1.47222598106e-05
# >  Recurse -3122 [-4332] -11 2.86579032289e-05
# >  Recurse -3122 [-4332] 11 2.86579032289e-05
# >  Recurse -3122 [-4332] 22 2.86579032289e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4324] 2.19411864239e-05
# >  Recurse -3122 [-4324] -4232 2.19411864239e-05
# ------>  Recurse -3122 [-4324, -4232] -3322 2.1782326915e-05
# ------------>  Recurse -3122 [-4324, -4232, -3322] -11 1.78273781212e-05
# ------------>  Recurse -3122 [-4324, -4232, -3322] 11 1.78273781212e-05
# ------------>  Recurse -3122 [-4324, -4232, -3322] 22 1.78273781212e-05
# ------>  Recurse -3122 [-4324, -4232] -3312 2.1782326915e-05
# ------------>  Recurse -3122 [-4324, -4232, -3312] -3112 3.11990959355e-07
# ------------------>  Recurse -3122 [-4324, -4232, -3312, -3112] -11 4.06140823751e-11
# ------------>  Recurse -3122 [-4324, -4232, -3312] -11 3.11990959355e-07
# ------------>  Recurse -3122 [-4324, -4232, -3312] 11 3.11990959355e-07
# ------------>  Recurse -3122 [-4324, -4232, -3312] 22 3.11990959355e-07
# ------>  Recurse -3122 [-4324, -4232] -11 2.1782326915e-05
# ------>  Recurse -3122 [-4324, -4232] 11 2.1782326915e-05
# ------>  Recurse -3122 [-4324, -4232] 22 2.1782326915e-05
# >  Recurse -3122 [-4324] -11 2.19411864239e-05
# >  Recurse -3122 [-4324] 11 2.19411864239e-05
# >  Recurse -3122 [-4324] 22 2.19411864239e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4314] 2.14493788684e-05
# >  Recurse -3122 [-4314] -4132 2.14493788684e-05
# ------>  Recurse -3122 [-4314, -4132] -3322 2.13946936172e-05
# ------------>  Recurse -3122 [-4314, -4132, -3322] -11 2.50883683399e-06
# ------------>  Recurse -3122 [-4314, -4132, -3322] 11 2.50883683399e-06
# ------------>  Recurse -3122 [-4314, -4132, -3322] 22 2.50883683399e-06
# ------>  Recurse -3122 [-4314, -4132] -3312 2.13946936172e-05
# ------------>  Recurse -3122 [-4314, -4132, -3312] -3112 1.2258856777e-05
# ------------------>  Recurse -3122 [-4314, -4132, -3312, -3112] -11 1.59677734873e-09
# ------------>  Recurse -3122 [-4314, -4132, -3312] -11 1.2258856777e-05
# ------------>  Recurse -3122 [-4314, -4132, -3312] 11 1.2258856777e-05
# ------------>  Recurse -3122 [-4314, -4132, -3312] 22 1.2258856777e-05
# ------>  Recurse -3122 [-4314, -4132] -3112 2.13946936172e-05
# ------------>  Recurse -3122 [-4314, -4132, -3112] -11 1.16249493192e-06
# ------>  Recurse -3122 [-4314, -4132] -11 2.13946936172e-05
# ------>  Recurse -3122 [-4314, -4132] 11 2.13946936172e-05
# ------>  Recurse -3122 [-4314, -4132] 22 2.13946936172e-05
# >  Recurse -3122 [-4314] -11 2.14493788684e-05
# >  Recurse -3122 [-4314] 11 2.14493788684e-05
# >  Recurse -3122 [-4314] 22 2.14493788684e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4232] 0.000608134134263
# >  Recurse -3122 [-4232] -3322 0.000608134134263
# ------>  Recurse -3122 [-4232, -3322] -11 0.000496656667379
# ------>  Recurse -3122 [-4232, -3322] 11 0.000496656667379
# ------>  Recurse -3122 [-4232, -3322] 22 0.000496656667379
# >  Recurse -3122 [-4232] -3312 0.000608134134263
# ------>  Recurse -3122 [-4232, -3312] -3112 8.69415614304e-06
# ------------>  Recurse -3122 [-4232, -3312, -3112] -11 1.12958664768e-09
# ------>  Recurse -3122 [-4232, -3312] -11 8.69415614304e-06
# ------>  Recurse -3122 [-4232, -3312] 11 8.69415614304e-06
# ------>  Recurse -3122 [-4232, -3312] 22 8.69415614304e-06
# >  Recurse -3122 [-4232] -11 0.000608134134263
# >  Recurse -3122 [-4232] 11 0.000608134134263
# >  Recurse -3122 [-4232] 22 0.000608134134263
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4224] 0.00013848176427
# >  Recurse -3122 [-4224] -4122 0.00013848176427
# ------>  Recurse -3122 [-4224, -4122] -3322 0.000139251307276
# ------------>  Recurse -3122 [-4224, -4122, -3322] -11 4.21336505728e-06
# ------------>  Recurse -3122 [-4224, -4122, -3322] 11 4.21336505728e-06
# ------------>  Recurse -3122 [-4224, -4122, -3322] 22 4.21336505728e-06
# ------>  Recurse -3122 [-4224, -4122] -3312 0.000139251307276
# ------------>  Recurse -3122 [-4224, -4122, -3312] -3112 1.51364893076e-06
# ------------------>  Recurse -3122 [-4224, -4122, -3312, -3112] -11 1.97067062499e-10
# ------------>  Recurse -3122 [-4224, -4122, -3312] -11 1.51364893076e-06
# ------------>  Recurse -3122 [-4224, -4122, -3312] 11 1.51364893076e-06
# ------------>  Recurse -3122 [-4224, -4122, -3312] 22 1.51364893076e-06
# ------>  Recurse -3122 [-4224, -4122] -3112 0.000139251307276
# ------------>  Recurse -3122 [-4224, -4122, -3112] -11 1.05516946805e-06
# ------>  Recurse -3122 [-4224, -4122] -11 0.000139251307276
# ------>  Recurse -3122 [-4224, -4122] 11 0.000139251307276
# ------>  Recurse -3122 [-4224, -4122] 22 0.000139251307276
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4222] 0.000693045157321
# >  Recurse -3122 [-4222] -4122 0.000693045157321
# ------>  Recurse -3122 [-4222, -4122] -3322 0.000690632035246
# ------------>  Recurse -3122 [-4222, -4122, -3322] -11 2.08965185487e-05
# ------------>  Recurse -3122 [-4222, -4122, -3322] 11 2.08965185487e-05
# ------------>  Recurse -3122 [-4222, -4122, -3322] 22 2.08965185487e-05
# ------>  Recurse -3122 [-4222, -4122] -3312 0.000690632035246
# ------------>  Recurse -3122 [-4222, -4122, -3312] -3112 7.5070108364e-06
# ------------------>  Recurse -3122 [-4222, -4122, -3312, -3112] -11 9.77175255942e-10
# ------------>  Recurse -3122 [-4222, -4122, -3312] -11 7.5070108364e-06
# ------------>  Recurse -3122 [-4222, -4122, -3312] 11 7.5070108364e-06
# ------------>  Recurse -3122 [-4222, -4122, -3312] 22 7.5070108364e-06
# ------>  Recurse -3122 [-4222, -4122] -3112 0.000690632035246
# ------------>  Recurse -3122 [-4222, -4122, -3112] -11 5.23318839318e-06
# ------>  Recurse -3122 [-4222, -4122] -11 0.000690632035246
# ------>  Recurse -3122 [-4222, -4122] 11 0.000690632035246
# ------>  Recurse -3122 [-4222, -4122] 22 0.000690632035246
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4214] 0.000134928300952
# >  Recurse -3122 [-4214] -4122 0.000134928300952
# ------>  Recurse -3122 [-4214, -4122] -3322 0.000135658165348
# ------------>  Recurse -3122 [-4214, -4122, -3322] -11 4.10424239673e-06
# ------------>  Recurse -3122 [-4214, -4122, -3322] 11 4.10424239673e-06
# ------------>  Recurse -3122 [-4214, -4122, -3322] 22 4.10424239673e-06
# ------>  Recurse -3122 [-4214, -4122] -3312 0.000135658165348
# ------------>  Recurse -3122 [-4214, -4122, -3312] -3112 1.47437085159e-06
# ------------------>  Recurse -3122 [-4214, -4122, -3312, -3112] -11 1.91972253966e-10
# ------------>  Recurse -3122 [-4214, -4122, -3312] -11 1.47437085159e-06
# ------------>  Recurse -3122 [-4214, -4122, -3312] 11 1.47437085159e-06
# ------------>  Recurse -3122 [-4214, -4122, -3312] 22 1.47437085159e-06
# ------>  Recurse -3122 [-4214, -4122] -3112 0.000135658165348
# ------------>  Recurse -3122 [-4214, -4122, -3112] -11 1.02786141061e-06
# ------>  Recurse -3122 [-4214, -4122] -11 0.000135658165348
# ------>  Recurse -3122 [-4214, -4122] 11 0.000135658165348
# ------>  Recurse -3122 [-4214, -4122] 22 0.000135658165348
# >  Recurse -3122 [-4214] -11 0.000134928300952
# >  Recurse -3122 [-4214] 11 0.000134928300952
# >  Recurse -3122 [-4214] 22 0.000134928300952
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4212] 0.000703291436347
# >  Recurse -3122 [-4212] -4122 0.000703291436347
# ------>  Recurse -3122 [-4212, -4122] -3322 0.000699897370744
# ------------>  Recurse -3122 [-4212, -4122, -3322] -11 2.11672017367e-05
# ------------>  Recurse -3122 [-4212, -4122, -3322] 11 2.11672017367e-05
# ------------>  Recurse -3122 [-4212, -4122, -3322] 22 2.11672017367e-05
# ------>  Recurse -3122 [-4212, -4122] -3312 0.000699897370744
# ------------>  Recurse -3122 [-4212, -4122, -3312] -3112 7.60436534937e-06
# ------------------>  Recurse -3122 [-4212, -4122, -3312, -3112] -11 9.89619848506e-10
# ------------>  Recurse -3122 [-4212, -4122, -3312] -11 7.60436534937e-06
# ------------>  Recurse -3122 [-4212, -4122, -3312] 11 7.60436534937e-06
# ------------>  Recurse -3122 [-4212, -4122, -3312] 22 7.60436534937e-06
# ------>  Recurse -3122 [-4212, -4122] -3112 0.000699897370744
# ------------>  Recurse -3122 [-4212, -4122, -3112] -11 5.30097980455e-06
# ------>  Recurse -3122 [-4212, -4122] -11 0.000699897370744
# ------>  Recurse -3122 [-4212, -4122] 11 0.000699897370744
# ------>  Recurse -3122 [-4212, -4122] 22 0.000699897370744
# >  Recurse -3122 [-4212] -11 0.000703291436347
# >  Recurse -3122 [-4212] 11 0.000703291436347
# >  Recurse -3122 [-4212] 22 0.000703291436347
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4132] 0.000606454492851
# >  Recurse -3122 [-4132] -3322 0.000606454492851
# ------>  Recurse -3122 [-4132, -3322] -11 7.05145923091e-05
# ------>  Recurse -3122 [-4132, -3322] 11 7.05145923091e-05
# ------>  Recurse -3122 [-4132, -3322] 22 7.05145923091e-05
# >  Recurse -3122 [-4132] -3312 0.000606454492851
# ------>  Recurse -3122 [-4132, -3312] -3112 0.000344322409668
# ------------>  Recurse -3122 [-4132, -3312, -3112] -11 4.47453420331e-08
# ------>  Recurse -3122 [-4132, -3312] -11 0.000344322409668
# ------>  Recurse -3122 [-4132, -3312] 11 0.000344322409668
# ------>  Recurse -3122 [-4132, -3312] 22 0.000344322409668
# >  Recurse -3122 [-4132] -3112 0.000606454492851
# ------>  Recurse -3122 [-4132, -3112] -11 3.2681864571e-05
# >  Recurse -3122 [-4132] -11 0.000606454492851
# >  Recurse -3122 [-4132] 11 0.000606454492851
# >  Recurse -3122 [-4132] 22 0.000606454492851
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4122] 0.00345975951628
# >  Recurse -3122 [-4122] -3322 0.00345975951628
# ------>  Recurse -3122 [-4122, -3322] -11 0.000103951644396
# ------>  Recurse -3122 [-4122, -3322] 11 0.000103951644396
# ------>  Recurse -3122 [-4122, -3322] 22 0.000103951644396
# >  Recurse -3122 [-4122] -3312 0.00345975951628
# ------>  Recurse -3122 [-4122, -3312] -3112 3.73489032223e-05
# ------------>  Recurse -3122 [-4122, -3312, -3112] -11 4.847719625e-09
# ------>  Recurse -3122 [-4122, -3312] -11 3.73489032223e-05
# ------>  Recurse -3122 [-4122, -3312] 11 3.73489032223e-05
# ------>  Recurse -3122 [-4122, -3312] 22 3.73489032223e-05
# >  Recurse -3122 [-4122] -3112 0.00345975951628
# ------>  Recurse -3122 [-4122, -3112] -11 2.60333557865e-05
# >  Recurse -3122 [-4122] -11 0.00345975951628
# >  Recurse -3122 [-4122] 11 0.00345975951628
# >  Recurse -3122 [-4122] 22 0.00345975951628
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4114] 0.000135377620931
# >  Recurse -3122 [-4114] -4122 0.000135377620931
# ------>  Recurse -3122 [-4114, -4122] -3322 0.000136235857579
# ------------>  Recurse -3122 [-4114, -4122, -3322] -11 4.13021766907e-06
# ------------>  Recurse -3122 [-4114, -4122, -3322] 11 4.13021766907e-06
# ------------>  Recurse -3122 [-4114, -4122, -3322] 22 4.13021766907e-06
# ------>  Recurse -3122 [-4114, -4122] -3312 0.000136235857579
# ------------>  Recurse -3122 [-4114, -4122, -3312] -3112 1.48375664646e-06
# ------------------>  Recurse -3122 [-4114, -4122, -3312, -3112] -11 1.93259709891e-10
# ------------>  Recurse -3122 [-4114, -4122, -3312] -11 1.48375664646e-06
# ------------>  Recurse -3122 [-4114, -4122, -3312] 11 1.48375664646e-06
# ------------>  Recurse -3122 [-4114, -4122, -3312] 22 1.48375664646e-06
# ------>  Recurse -3122 [-4114, -4122] -3112 0.000136235857579
# ------------>  Recurse -3122 [-4114, -4122, -3112] -11 1.03426077415e-06
# ------>  Recurse -3122 [-4114, -4122] -11 0.000136235857579
# ------>  Recurse -3122 [-4114, -4122] 11 0.000136235857579
# ------>  Recurse -3122 [-4114, -4122] 22 0.000136235857579
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-4112] 0.000701323369684
# >  Recurse -3122 [-4112] -4122 0.000701323369684
# ------>  Recurse -3122 [-4112, -4122] -3322 0.000697693633483
# ------------>  Recurse -3122 [-4112, -4122, -3322] -11 2.10926764131e-05
# ------------>  Recurse -3122 [-4112, -4122, -3322] 11 2.10926764131e-05
# ------------>  Recurse -3122 [-4112, -4122, -3322] 22 2.10926764131e-05
# ------>  Recurse -3122 [-4112, -4122] -3312 0.000697693633483
# ------------>  Recurse -3122 [-4112, -4122, -3312] -3112 7.57738717883e-06
# ------------------>  Recurse -3122 [-4112, -4122, -3312, -3112] -11 9.86078854876e-10
# ------------>  Recurse -3122 [-4112, -4122, -3312] -11 7.57738717883e-06
# ------------>  Recurse -3122 [-4112, -4122, -3312] 11 7.57738717883e-06
# ------------>  Recurse -3122 [-4112, -4122, -3312] 22 7.57738717883e-06
# ------>  Recurse -3122 [-4112, -4122] -3112 0.000697693633483
# ------------>  Recurse -3122 [-4112, -4122, -3112] -11 5.28247438995e-06
# ------>  Recurse -3122 [-4112, -4122] -11 0.000697693633483
# ------>  Recurse -3122 [-4112, -4122] 11 0.000697693633483
# ------>  Recurse -3122 [-4112, -4122] 22 0.000697693633483
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3334] 0.00316662846434
# >  Recurse -3122 [-3334] -3322 0.00316662846434
# ------>  Recurse -3122 [-3334, -3322] -11 0.000866738335168
# ------>  Recurse -3122 [-3334, -3322] 11 0.000866738335168
# ------>  Recurse -3122 [-3334, -3322] 22 0.000866738335168
# >  Recurse -3122 [-3334] -3312 0.00316662846434
# ------>  Recurse -3122 [-3334, -3312] -3112 0.000308475693397
# ------------>  Recurse -3122 [-3334, -3312, -3112] -11 3.93725861486e-08
# ------>  Recurse -3122 [-3334, -3312] -11 0.000308475693397
# ------>  Recurse -3122 [-3334, -3312] 11 0.000308475693397
# ------>  Recurse -3122 [-3334, -3312] 22 0.000308475693397
# >  Recurse -3122 [-3334] -11 0.00316662846434
# >  Recurse -3122 [-3334] 11 0.00316662846434
# >  Recurse -3122 [-3334] 22 0.00316662846434
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3324] 0.0133219692486
# >  Recurse -3122 [-3324] -3322 0.0133219692486
# ------>  Recurse -3122 [-3324, -3322] -11 0.00467952290639
# ------>  Recurse -3122 [-3324, -3322] 11 0.00467952290639
# ------>  Recurse -3122 [-3324, -3322] 22 0.00467952290639
# >  Recurse -3122 [-3324] -3312 0.0133219692486
# ------>  Recurse -3122 [-3324, -3312] -3112 0.00931207437598
# ------------>  Recurse -3122 [-3324, -3312, -3112] -11 1.18864400893e-06
# ------>  Recurse -3122 [-3324, -3312] -11 0.00931207437598
# ------>  Recurse -3122 [-3324, -3312] 11 0.00931207437598
# ------>  Recurse -3122 [-3324, -3312] 22 0.00931207437598
# >  Recurse -3122 [-3324] -11 0.0133219692486
# >  Recurse -3122 [-3324] 11 0.0133219692486
# >  Recurse -3122 [-3324] 22 0.0133219692486
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3322] 0.139840501046
# >  Recurse -3122 [-3322] -11 0.139840501046
# >  Recurse -3122 [-3322] 11 0.139840501046
# >  Recurse -3122 [-3322] 22 0.139840501046
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3314] 0.0136478132226
# >  Recurse -3122 [-3314] -3322 0.0136478132226
# ------>  Recurse -3122 [-3314, -3322] -11 0.00962968619073
# ------>  Recurse -3122 [-3314, -3322] 11 0.00962968619073
# ------>  Recurse -3122 [-3314, -3322] 22 0.00962968619073
# >  Recurse -3122 [-3314] -3312 0.0136478132226
# ------>  Recurse -3122 [-3314, -3312] -3112 0.00477721954364
# ------------>  Recurse -3122 [-3314, -3312, -3112] -11 6.0991964993e-07
# ------>  Recurse -3122 [-3314, -3312] -11 0.00477721954364
# ------>  Recurse -3122 [-3314, -3312] 11 0.00477721954364
# ------>  Recurse -3122 [-3314, -3312] 22 0.00477721954364
# >  Recurse -3122 [-3314] -11 0.0136478132226
# >  Recurse -3122 [-3314] 11 0.0136478132226
# >  Recurse -3122 [-3314] 22 0.0136478132226
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3312] 0.140877664649
# >  Recurse -3122 [-3312] -3112 0.140877664649
# ------>  Recurse -3122 [-3312, -3112] -11 1.75220755192e-05
# >  Recurse -3122 [-3312] -11 0.140877664649
# >  Recurse -3122 [-3312] 11 0.140877664649
# >  Recurse -3122 [-3312] 22 0.140877664649
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3224] 0.0573016976901
# >  Recurse -3122 [-3224] -11 0.0573016976901
# >  Recurse -3122 [-3224] 11 0.0573016976901
# >  Recurse -3122 [-3224] 22 0.0573016976901
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3222] 0.518164365193
# >  Recurse -3122 [-3222] -11 0.518164365193
# >  Recurse -3122 [-3222] 11 0.518164365193
# >  Recurse -3122 [-3222] 22 0.518164365193
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3214] 0.0589605604144
# >  Recurse -3122 [-3214] -3112 0.0589605604144
# ------>  Recurse -3122 [-3214, -3112] -11 0.00357252695305
# >  Recurse -3122 [-3214] -11 0.0589605604144
# >  Recurse -3122 [-3214] 11 0.0589605604144
# >  Recurse -3122 [-3214] 22 0.0589605604144
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3212] 0.569758019938
# >  Recurse -3122 [-3212] -11 0.569758019938
# >  Recurse -3122 [-3212] 11 0.569758019938
# >  Recurse -3122 [-3212] 22 0.569758019938
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3114] 0.0640152683506
# >  Recurse -3122 [-3114] -3112 0.0640152683506
# ------>  Recurse -3122 [-3114, -3112] -11 0.00395215173207
# >  Recurse -3122 [-3114] -11 0.0640152683506
# >  Recurse -3122 [-3114] 11 0.0640152683506
# >  Recurse -3122 [-3114] 22 0.0640152683506
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-3112] 0.557309279602
# >  Recurse -3122 [-3112] -11 0.557309279602
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-2224] 0.222224662917
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-2214] 0.223401920076
# >  Recurse -3122 [-2214] -11 0.223401920076
# >  Recurse -3122 [-2214] 11 0.223401920076
# >  Recurse -3122 [-2214] 22 0.223401920076
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-2114] 0.232162903957
# >  Recurse -3122 [-2114] -11 0.232162903957
# >  Recurse -3122 [-2114] 11 0.232162903957
# >  Recurse -3122 [-2114] 22 0.232162903957
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-1114] 0.233963692562
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-433] 0.00480288861101
# >  Recurse -3122 [-433] -11 0.00480288861101
# >  Recurse -3122 [-433] 11 0.00480288861101
# >  Recurse -3122 [-433] 22 0.00480288861101
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-413] 0.0177095730662
# >  Recurse -3122 [-413] -11 0.0177095730662
# >  Recurse -3122 [-413] 11 0.0177095730662
# >  Recurse -3122 [-413] 22 0.0177095730662
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-323] 4.02482761332
# >  Recurse -3122 [-323] -11 4.02482761332
# >  Recurse -3122 [-323] 11 4.02482761332
# >  Recurse -3122 [-323] 22 4.02482761332
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-313] 4.16182889761
# >  Recurse -3122 [-313] -11 4.16182889761
# >  Recurse -3122 [-313] 11 4.16182889761
# >  Recurse -3122 [-313] 22 4.16182889761
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [-213] 26.2583776464
# >  Recurse -3122 [-213] -11 26.2583776464
# >  Recurse -3122 [-213] 11 26.2583776464
# >  Recurse -3122 [-213] 22 26.2583776464
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [111] 89.2232253543
# >  Recurse -3122 [111] -11 89.2232253543
# >  Recurse -3122 [111] 11 89.2232253543
# >  Recurse -3122 [111] 22 89.2232253543
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [113] 27.040675282
# >  Recurse -3122 [113] -11 27.040675282
# >  Recurse -3122 [113] 11 27.040675282
# >  Recurse -3122 [113] 22 27.040675282
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [213] 28.00322989
# >  Recurse -3122 [213] -11 28.00322989
# >  Recurse -3122 [213] 11 28.00322989
# >  Recurse -3122 [213] 22 28.00322989
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [221] 35.9225391471
# >  Recurse -3122 [221] -11 35.9225391471
# >  Recurse -3122 [221] 11 35.9225391471
# >  Recurse -3122 [221] 22 35.9225391471
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [223] 26.8378662299
# >  Recurse -3122 [223] -11 26.8378662299
# >  Recurse -3122 [223] 11 26.8378662299
# >  Recurse -3122 [223] 22 26.8378662299
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [313] 6.32587116159
# >  Recurse -3122 [313] -11 6.32587116159
# >  Recurse -3122 [313] 11 6.32587116159
# >  Recurse -3122 [313] 22 6.32587116159
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [323] 6.46161103066
# >  Recurse -3122 [323] -11 6.46161103066
# >  Recurse -3122 [323] 11 6.46161103066
# >  Recurse -3122 [323] 22 6.46161103066
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [331] 19.1097481652
# >  Recurse -3122 [331] -11 19.1097481652
# >  Recurse -3122 [331] 11 19.1097481652
# >  Recurse -3122 [331] 22 19.1097481652
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [333] 0.97365101368
# >  Recurse -3122 [333] -11 0.97365101368
# >  Recurse -3122 [333] 11 0.97365101368
# >  Recurse -3122 [333] 22 0.97365101368
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [413] 0.0172591381026
# >  Recurse -3122 [413] -11 0.0172591381026
# >  Recurse -3122 [413] 11 0.0172591381026
# >  Recurse -3122 [413] 22 0.0172591381026
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [433] 0.0047506125008
# >  Recurse -3122 [433] -11 0.0047506125008
# >  Recurse -3122 [433] 11 0.0047506125008
# >  Recurse -3122 [433] 22 0.0047506125008
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [441] 2.91178512519e-05
# >  Recurse -3122 [441] -3322 2.91178512519e-05
# ------>  Recurse -3122 [441, -3322] -11 2.55884439001e-08
# ------>  Recurse -3122 [441, -3322] 11 2.55884439001e-08
# ------>  Recurse -3122 [441, -3322] 22 2.55884439001e-08
# >  Recurse -3122 [441] -3312 2.91178512519e-05
# ------>  Recurse -3122 [441, -3312] -3112 2.55823662688e-08
# ------------>  Recurse -3122 [441, -3312, -3112] -11 3.3455791912e-12
# ------>  Recurse -3122 [441, -3312] -11 2.55823662688e-08
# ------>  Recurse -3122 [441, -3312] 11 2.55823662688e-08
# ------>  Recurse -3122 [441, -3312] 22 2.55823662688e-08
# >  Recurse -3122 [441] -3112 2.91178512519e-05
# ------>  Recurse -3122 [441, -3112] -11 2.96832790086e-07
# >  Recurse -3122 [441] -11 2.91178512519e-05
# >  Recurse -3122 [441] 11 2.91178512519e-05
# >  Recurse -3122 [441] 22 2.91178512519e-05
# >  Recurse -3122 [441] 3112 2.91178512519e-05
# ------>  Recurse -3122 [441, 3112] 11 3.00159942428e-07
# >  Recurse -3122 [441] 3312 2.91178512519e-05
# ------>  Recurse -3122 [441, 3312] -11 2.59972291002e-08
# ------>  Recurse -3122 [441, 3312] 11 2.59972291002e-08
# ------>  Recurse -3122 [441, 3312] 22 2.59972291002e-08
# ------>  Recurse -3122 [441, 3312] 3112 2.59972291002e-08
# ------------>  Recurse -3122 [441, 3312, 3112] 11 3.36284067265e-12
# >  Recurse -3122 [441] 3322 2.91178512519e-05
# ------>  Recurse -3122 [441, 3322] -11 2.58792560735e-08
# ------>  Recurse -3122 [441, 3322] 11 2.58792560735e-08
# ------>  Recurse -3122 [441, 3322] 22 2.58792560735e-08
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [443] 4.46624341937e-05
# >  Recurse -3122 [443] -3322 4.46624341937e-05
# ------>  Recurse -3122 [443, -3322] -11 1.13543927848e-07
# ------>  Recurse -3122 [443, -3322] 11 1.13543927848e-07
# ------>  Recurse -3122 [443, -3322] 22 1.13543927848e-07
# >  Recurse -3122 [443] -3312 4.46624341937e-05
# ------>  Recurse -3122 [443, -3312] -3112 1.13275565053e-07
# ------------>  Recurse -3122 [443, -3312, -3112] -11 1.47958944254e-11
# ------>  Recurse -3122 [443, -3312] -11 1.13275565053e-07
# ------>  Recurse -3122 [443, -3312] 11 1.13275565053e-07
# ------>  Recurse -3122 [443, -3312] 22 1.13275565053e-07
# >  Recurse -3122 [443] -3112 4.46624341937e-05
# ------>  Recurse -3122 [443, -3112] -11 5.34244489189e-07
# >  Recurse -3122 [443] -11 4.46624341937e-05
# >  Recurse -3122 [443] 11 4.46624341937e-05
# >  Recurse -3122 [443] 22 4.46624341937e-05
# >  Recurse -3122 [443] 3112 4.46624341937e-05
# ------>  Recurse -3122 [443, 3112] 11 5.45299663165e-07
# >  Recurse -3122 [443] 3312 4.46624341937e-05
# ------>  Recurse -3122 [443, 3312] -11 1.18007824692e-07
# ------>  Recurse -3122 [443, 3312] 11 1.18007824692e-07
# ------>  Recurse -3122 [443, 3312] 22 1.18007824692e-07
# ------>  Recurse -3122 [443, 3312] 3112 1.18007824692e-07
# ------------>  Recurse -3122 [443, 3312, 3112] 11 1.52471085651e-11
# >  Recurse -3122 [443] 3322 4.46624341937e-05
# ------>  Recurse -3122 [443, 3322] -11 1.17865064554e-07
# ------>  Recurse -3122 [443, 3322] 11 1.17865064554e-07
# ------>  Recurse -3122 [443, 3322] 22 1.17865064554e-07
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [1114] 7.6910535344
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [2114] 6.21484716982
# >  Recurse -3122 [2114] -11 6.21484716982
# >  Recurse -3122 [2114] 11 6.21484716982
# >  Recurse -3122 [2114] 22 6.21484716982
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [2214] 6.26399393808
# >  Recurse -3122 [2214] -11 6.26399393808
# >  Recurse -3122 [2214] 11 6.26399393808
# >  Recurse -3122 [2214] 22 6.26399393808
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [2224] 7.87044206164
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3112] 2.77248661462
# >  Recurse -3122 [3112] 11 2.77248661462
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3114] 0.603544968466
# >  Recurse -3122 [3114] -11 0.603544968466
# >  Recurse -3122 [3114] 11 0.603544968466
# >  Recurse -3122 [3114] 22 0.603544968466
# >  Recurse -3122 [3114] 3112 0.603544968466
# ------>  Recurse -3122 [3114, 3112] 11 0.0311505103151
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3212] 3.16968386438
# >  Recurse -3122 [3212] -11 3.16968386438
# >  Recurse -3122 [3212] 11 3.16968386438
# >  Recurse -3122 [3212] 22 3.16968386438
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3214] 0.657590822179
# >  Recurse -3122 [3214] -11 0.657590822179
# >  Recurse -3122 [3214] 11 0.657590822179
# >  Recurse -3122 [3214] 22 0.657590822179
# >  Recurse -3122 [3214] 3112 0.657590822179
# ------>  Recurse -3122 [3214, 3112] 11 0.0331796333601
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3222] 3.58984758892
# >  Recurse -3122 [3222] -11 3.58984758892
# >  Recurse -3122 [3222] 11 3.58984758892
# >  Recurse -3122 [3222] 22 3.58984758892
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3224] 0.806921626876
# >  Recurse -3122 [3224] -11 0.806921626876
# >  Recurse -3122 [3224] 11 0.806921626876
# >  Recurse -3122 [3224] 22 0.806921626876
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3312] 0.259017117065
# >  Recurse -3122 [3312] -11 0.259017117065
# >  Recurse -3122 [3312] 11 0.259017117065
# >  Recurse -3122 [3312] 22 0.259017117065
# >  Recurse -3122 [3312] 3112 0.259017117065
# ------>  Recurse -3122 [3312, 3112] 11 3.00385799149e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3314] 0.0519425953315
# >  Recurse -3122 [3314] -11 0.0519425953315
# >  Recurse -3122 [3314] 11 0.0519425953315
# >  Recurse -3122 [3314] 22 0.0519425953315
# >  Recurse -3122 [3314] 3312 0.0519425953315
# ------>  Recurse -3122 [3314, 3312] -11 0.0164148086912
# ------>  Recurse -3122 [3314, 3312] 11 0.0164148086912
# ------>  Recurse -3122 [3314, 3312] 22 0.0164148086912
# ------>  Recurse -3122 [3314, 3312] 3112 0.0164148086912
# ------------>  Recurse -3122 [3314, 3312, 3112] 11 1.9681097098e-06
# >  Recurse -3122 [3314] 3322 0.0519425953315
# ------>  Recurse -3122 [3314, 3322] -11 0.0330284127948
# ------>  Recurse -3122 [3314, 3322] 11 0.0330284127948
# ------>  Recurse -3122 [3314, 3322] 22 0.0330284127948
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3322] 0.292228622727
# >  Recurse -3122 [3322] -11 0.292228622727
# >  Recurse -3122 [3322] 11 0.292228622727
# >  Recurse -3122 [3322] 22 0.292228622727
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3324] 0.0605201356091
# >  Recurse -3122 [3324] -11 0.0605201356091
# >  Recurse -3122 [3324] 11 0.0605201356091
# >  Recurse -3122 [3324] 22 0.0605201356091
# >  Recurse -3122 [3324] 3312 0.0605201356091
# ------>  Recurse -3122 [3324, 3312] -11 0.037890069033
# ------>  Recurse -3122 [3324, 3312] 11 0.037890069033
# ------>  Recurse -3122 [3324, 3312] 22 0.037890069033
# ------>  Recurse -3122 [3324, 3312] 3112 0.037890069033
# ------------>  Recurse -3122 [3324, 3312, 3112] 11 4.51437867178e-06
# >  Recurse -3122 [3324] 3322 0.0605201356091
# ------>  Recurse -3122 [3324, 3322] -11 0.0189757507663
# ------>  Recurse -3122 [3324, 3322] 11 0.0189757507663
# ------>  Recurse -3122 [3324, 3322] 22 0.0189757507663
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [3334] 0.00165936642488
# >  Recurse -3122 [3334] -11 0.00165936642488
# >  Recurse -3122 [3334] 11 0.00165936642488
# >  Recurse -3122 [3334] 22 0.00165936642488
# >  Recurse -3122 [3334] 3312 0.00165936642488
# ------>  Recurse -3122 [3334, 3312] -11 0.000164288558097
# ------>  Recurse -3122 [3334, 3312] 11 0.000164288558097
# ------>  Recurse -3122 [3334, 3312] 22 0.000164288558097
# ------>  Recurse -3122 [3334, 3312] 3112 0.000164288558097
# ------------>  Recurse -3122 [3334, 3312, 3112] 11 2.0906490384e-08
# >  Recurse -3122 [3334] 3322 0.00165936642488
# ------>  Recurse -3122 [3334, 3322] -11 0.000461656962345
# ------>  Recurse -3122 [3334, 3322] 11 0.000461656962345
# ------>  Recurse -3122 [3334, 3322] 22 0.000461656962345
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4112] 0.00143226899514
# >  Recurse -3122 [4112] 4122 0.00143226899514
# ------>  Recurse -3122 [4112, 4122] -11 0.00134324324719
# ------>  Recurse -3122 [4112, 4122] 11 0.00134324324719
# ------>  Recurse -3122 [4112, 4122] 22 0.00134324324719
# ------>  Recurse -3122 [4112, 4122] 3112 0.00134324324719
# ------------>  Recurse -3122 [4112, 4122, 3112] 11 9.60972376401e-06
# ------>  Recurse -3122 [4112, 4122] 3312 0.00134324324719
# ------------>  Recurse -3122 [4112, 4122, 3312] -11 1.38375674488e-05
# ------------>  Recurse -3122 [4112, 4122, 3312] 11 1.38375674488e-05
# ------------>  Recurse -3122 [4112, 4122, 3312] 22 1.38375674488e-05
# ------------>  Recurse -3122 [4112, 4122, 3312] 3112 1.38375674488e-05
# ------------------>  Recurse -3122 [4112, 4122, 3312, 3112] 11 1.74474703885e-09
# ------>  Recurse -3122 [4112, 4122] 3322 0.00134324324719
# ------------>  Recurse -3122 [4112, 4122, 3322] -11 3.83819524654e-05
# ------------>  Recurse -3122 [4112, 4122, 3322] 11 3.83819524654e-05
# ------------>  Recurse -3122 [4112, 4122, 3322] 22 3.83819524654e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4114] 0.000313228272816
# >  Recurse -3122 [4114] 4122 0.000313228272816
# ------>  Recurse -3122 [4114, 4122] -11 0.000297490366434
# ------>  Recurse -3122 [4114, 4122] 11 0.000297490366434
# ------>  Recurse -3122 [4114, 4122] 22 0.000297490366434
# ------>  Recurse -3122 [4114, 4122] 3112 0.000297490366434
# ------------>  Recurse -3122 [4114, 4122, 3112] 11 2.1229700522e-06
# ------>  Recurse -3122 [4114, 4122] 3312 0.000297490366434
# ------------>  Recurse -3122 [4114, 4122, 3312] -11 3.05528952751e-06
# ------------>  Recurse -3122 [4114, 4122, 3312] 11 3.05528952751e-06
# ------------>  Recurse -3122 [4114, 4122, 3312] 22 3.05528952751e-06
# ------------>  Recurse -3122 [4114, 4122, 3312] 3112 3.05528952751e-06
# ------------------>  Recurse -3122 [4114, 4122, 3312, 3112] 11 3.85055165762e-10
# ------>  Recurse -3122 [4114, 4122] 3322 0.000297490366434
# ------------>  Recurse -3122 [4114, 4122, 3322] -11 8.47524975716e-06
# ------------>  Recurse -3122 [4114, 4122, 3322] 11 8.47524975716e-06
# ------------>  Recurse -3122 [4114, 4122, 3322] 22 8.47524975716e-06
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4122] 0.00541468880189
# >  Recurse -3122 [4122] -11 0.00541468880189
# >  Recurse -3122 [4122] 11 0.00541468880189
# >  Recurse -3122 [4122] 22 0.00541468880189
# >  Recurse -3122 [4122] 3112 0.00541468880189
# ------>  Recurse -3122 [4122, 3112] 11 3.76897310097e-05
# >  Recurse -3122 [4122] 3312 0.00541468880189
# ------>  Recurse -3122 [4122, 3312] -11 5.42464382291e-05
# ------>  Recurse -3122 [4122, 3312] 11 5.42464382291e-05
# ------>  Recurse -3122 [4122, 3312] 22 5.42464382291e-05
# ------>  Recurse -3122 [4122, 3312] 3112 5.42464382291e-05
# ------------>  Recurse -3122 [4122, 3312, 3112] 11 6.7165777702e-09
# >  Recurse -3122 [4122] 3322 0.00541468880189
# ------>  Recurse -3122 [4122, 3322] -11 0.000150427982926
# ------>  Recurse -3122 [4122, 3322] 11 0.000150427982926
# ------>  Recurse -3122 [4122, 3322] 22 0.000150427982926
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4132] 0.000641370210077
# >  Recurse -3122 [4132] -11 0.000641370210077
# >  Recurse -3122 [4132] 11 0.000641370210077
# >  Recurse -3122 [4132] 22 0.000641370210077
# >  Recurse -3122 [4132] 3112 0.000641370210077
# ------>  Recurse -3122 [4132, 3112] 11 3.44330302984e-05
# >  Recurse -3122 [4132] 3312 0.000641370210077
# ------>  Recurse -3122 [4132, 3312] -11 0.00036269865516
# ------>  Recurse -3122 [4132, 3312] 11 0.00036269865516
# ------>  Recurse -3122 [4132, 3312] 22 0.00036269865516
# ------>  Recurse -3122 [4132, 3312] 3112 0.00036269865516
# ------------>  Recurse -3122 [4132, 3312, 3112] 11 4.65760629485e-08
# >  Recurse -3122 [4132] 3322 0.000641370210077
# ------>  Recurse -3122 [4132, 3322] -11 7.43146260167e-05
# ------>  Recurse -3122 [4132, 3322] 11 7.43146260167e-05
# ------>  Recurse -3122 [4132, 3322] 22 7.43146260167e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4212] 0.00147151325429
# >  Recurse -3122 [4212] -11 0.00147151325429
# >  Recurse -3122 [4212] 11 0.00147151325429
# >  Recurse -3122 [4212] 22 0.00147151325429
# >  Recurse -3122 [4212] 4122 0.00147151325429
# ------>  Recurse -3122 [4212, 4122] -11 0.00137719316617
# ------>  Recurse -3122 [4212, 4122] 11 0.00137719316617
# ------>  Recurse -3122 [4212, 4122] 22 0.00137719316617
# ------>  Recurse -3122 [4212, 4122] 3112 0.00137719316617
# ------------>  Recurse -3122 [4212, 4122, 3112] 11 9.83751943067e-06
# ------>  Recurse -3122 [4212, 4122] 3312 0.00137719316617
# ------------>  Recurse -3122 [4212, 4122, 3312] -11 1.41650375613e-05
# ------------>  Recurse -3122 [4212, 4122, 3312] 11 1.41650375613e-05
# ------------>  Recurse -3122 [4212, 4122, 3312] 22 1.41650375613e-05
# ------------>  Recurse -3122 [4212, 4122, 3312] 3112 1.41650375613e-05
# ------------------>  Recurse -3122 [4212, 4122, 3312, 3112] 11 1.78524526782e-09
# ------>  Recurse -3122 [4212, 4122] 3322 0.00137719316617
# ------------>  Recurse -3122 [4212, 4122, 3322] -11 3.92894257464e-05
# ------------>  Recurse -3122 [4212, 4122, 3322] 11 3.92894257464e-05
# ------------>  Recurse -3122 [4212, 4122, 3322] 22 3.92894257464e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4214] 0.000332510084004
# >  Recurse -3122 [4214] -11 0.000332510084004
# >  Recurse -3122 [4214] 11 0.000332510084004
# >  Recurse -3122 [4214] 22 0.000332510084004
# >  Recurse -3122 [4214] 4122 0.000332510084004
# ------>  Recurse -3122 [4214, 4122] -11 0.000314635147111
# ------>  Recurse -3122 [4214, 4122] 11 0.000314635147111
# ------>  Recurse -3122 [4214, 4122] 22 0.000314635147111
# ------>  Recurse -3122 [4214, 4122] 3112 0.000314635147111
# ------------>  Recurse -3122 [4214, 4122, 3112] 11 2.239263354e-06
# ------>  Recurse -3122 [4214, 4122] 3312 0.000314635147111
# ------------>  Recurse -3122 [4214, 4122, 3312] -11 3.22173556457e-06
# ------------>  Recurse -3122 [4214, 4122, 3312] 11 3.22173556457e-06
# ------------>  Recurse -3122 [4214, 4122, 3312] 22 3.22173556457e-06
# ------------>  Recurse -3122 [4214, 4122, 3312] 3112 3.22173556457e-06
# ------------------>  Recurse -3122 [4214, 4122, 3312, 3112] 11 4.05780046033e-10
# ------>  Recurse -3122 [4214, 4122] 3322 0.000314635147111
# ------------>  Recurse -3122 [4214, 4122, 3322] -11 8.93755138179e-06
# ------------>  Recurse -3122 [4214, 4122, 3322] 11 8.93755138179e-06
# ------------>  Recurse -3122 [4214, 4122, 3322] 22 8.93755138179e-06
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4222] 0.00173522437172
# >  Recurse -3122 [4222] 4122 0.00173522437172
# ------>  Recurse -3122 [4222, 4122] -11 0.00160434483449
# ------>  Recurse -3122 [4222, 4122] 11 0.00160434483449
# ------>  Recurse -3122 [4222, 4122] 22 0.00160434483449
# ------>  Recurse -3122 [4222, 4122] 3112 0.00160434483449
# ------------>  Recurse -3122 [4222, 4122, 3112] 11 1.13408883769e-05
# ------>  Recurse -3122 [4222, 4122] 3312 0.00160434483449
# ------------>  Recurse -3122 [4222, 4122, 3312] -11 1.63208612902e-05
# ------------>  Recurse -3122 [4222, 4122, 3312] 11 1.63208612902e-05
# ------------>  Recurse -3122 [4222, 4122, 3312] 22 1.63208612902e-05
# ------------>  Recurse -3122 [4222, 4122, 3312] 3112 1.63208612902e-05
# ------------------>  Recurse -3122 [4222, 4122, 3312, 3112] 11 2.05097334369e-09
# ------>  Recurse -3122 [4222, 4122] 3322 0.00160434483449
# ------------>  Recurse -3122 [4222, 4122, 3322] -11 4.5274710486e-05
# ------------>  Recurse -3122 [4222, 4122, 3322] 11 4.5274710486e-05
# ------------>  Recurse -3122 [4222, 4122, 3322] 22 4.5274710486e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4224] 0.000397514657996
# >  Recurse -3122 [4224] 4122 0.000397514657996
# ------>  Recurse -3122 [4224, 4122] -11 0.000373159507227
# ------>  Recurse -3122 [4224, 4122] 11 0.000373159507227
# ------>  Recurse -3122 [4224, 4122] 22 0.000373159507227
# ------>  Recurse -3122 [4224, 4122] 3112 0.000373159507227
# ------------>  Recurse -3122 [4224, 4122, 3112] 11 2.63017619214e-06
# ------>  Recurse -3122 [4224, 4122] 3312 0.000373159507227
# ------------>  Recurse -3122 [4224, 4122, 3312] -11 3.78150904717e-06
# ------------>  Recurse -3122 [4224, 4122, 3312] 11 3.78150904717e-06
# ------------>  Recurse -3122 [4224, 4122, 3312] 22 3.78150904717e-06
# ------------>  Recurse -3122 [4224, 4122, 3312] 3112 3.78150904717e-06
# ------------------>  Recurse -3122 [4224, 4122, 3312, 3112] 11 4.75177616832e-10
# ------>  Recurse -3122 [4224, 4122] 3322 0.000373159507227
# ------------>  Recurse -3122 [4224, 4122, 3322] -11 1.04920223258e-05
# ------------>  Recurse -3122 [4224, 4122, 3322] 11 1.04920223258e-05
# ------------>  Recurse -3122 [4224, 4122, 3322] 22 1.04920223258e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4232] 0.000652074381518
# >  Recurse -3122 [4232] -11 0.000652074381518
# >  Recurse -3122 [4232] 11 0.000652074381518
# >  Recurse -3122 [4232] 22 0.000652074381518
# >  Recurse -3122 [4232] 3312 0.000652074381518
# ------>  Recurse -3122 [4232, 3312] -11 9.23538553975e-06
# ------>  Recurse -3122 [4232, 3312] 11 9.23538553975e-06
# ------>  Recurse -3122 [4232, 3312] 22 9.23538553975e-06
# ------>  Recurse -3122 [4232, 3312] 3112 9.23538553975e-06
# ------------>  Recurse -3122 [4232, 3312, 3112] 11 1.18511535108e-09
# >  Recurse -3122 [4232] 3322 0.000652074381518
# ------>  Recurse -3122 [4232, 3322] -11 0.000529360201027
# ------>  Recurse -3122 [4232, 3322] 11 0.000529360201027
# ------>  Recurse -3122 [4232, 3322] 22 0.000529360201027
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4314] 2.67204272833e-05
# >  Recurse -3122 [4314] -11 2.67204272833e-05
# >  Recurse -3122 [4314] 11 2.67204272833e-05
# >  Recurse -3122 [4314] 22 2.67204272833e-05
# >  Recurse -3122 [4314] 4132 2.67204272833e-05
# ------>  Recurse -3122 [4314, 4132] -11 2.65326718851e-05
# ------>  Recurse -3122 [4314, 4132] 11 2.65326718851e-05
# ------>  Recurse -3122 [4314, 4132] 22 2.65326718851e-05
# ------>  Recurse -3122 [4314, 4132] 3112 2.65326718851e-05
# ------------>  Recurse -3122 [4314, 4132, 3112] 11 1.42324458797e-06
# ------>  Recurse -3122 [4314, 4132] 3312 2.65326718851e-05
# ------------>  Recurse -3122 [4314, 4132, 3312] -11 1.49906995291e-05
# ------------>  Recurse -3122 [4314, 4132, 3312] 11 1.49906995291e-05
# ------------>  Recurse -3122 [4314, 4132, 3312] 22 1.49906995291e-05
# ------------>  Recurse -3122 [4314, 4132, 3312] 3112 1.49906995291e-05
# ------------------>  Recurse -3122 [4314, 4132, 3312, 3112] 11 1.92326483443e-09
# ------>  Recurse -3122 [4314, 4132] 3322 2.65326718851e-05
# ------------>  Recurse -3122 [4314, 4132, 3322] -11 3.07248072061e-06
# ------------>  Recurse -3122 [4314, 4132, 3322] 11 3.07248072061e-06
# ------------>  Recurse -3122 [4314, 4132, 3322] 22 3.07248072061e-06
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4324] 2.96010749909e-05
# >  Recurse -3122 [4324] -11 2.96010749909e-05
# >  Recurse -3122 [4324] 11 2.96010749909e-05
# >  Recurse -3122 [4324] 22 2.96010749909e-05
# >  Recurse -3122 [4324] 4232 2.96010749909e-05
# ------>  Recurse -3122 [4324, 4232] -11 2.9174123094e-05
# ------>  Recurse -3122 [4324, 4232] 11 2.9174123094e-05
# ------>  Recurse -3122 [4324, 4232] 22 2.9174123094e-05
# ------>  Recurse -3122 [4324, 4232] 3312 2.9174123094e-05
# ------------>  Recurse -3122 [4324, 4232, 3312] -11 4.11100196016e-07
# ------------>  Recurse -3122 [4324, 4232, 3312] 11 4.11100196016e-07
# ------------>  Recurse -3122 [4324, 4232, 3312] 22 4.11100196016e-07
# ------------>  Recurse -3122 [4324, 4232, 3312] 3112 4.11100196016e-07
# ------------------>  Recurse -3122 [4324, 4232, 3312, 3112] 11 5.26283092597e-11
# ------>  Recurse -3122 [4324, 4232] 3322 2.9174123094e-05
# ------------>  Recurse -3122 [4324, 4232, 3322] -11 2.35428043984e-05
# ------------>  Recurse -3122 [4324, 4232, 3322] 11 2.35428043984e-05
# ------------>  Recurse -3122 [4324, 4232, 3322] 22 2.35428043984e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [4332] 2.34584924126e-05
# >  Recurse -3122 [4332] -11 2.34584924126e-05
# >  Recurse -3122 [4332] 11 2.34584924126e-05
# >  Recurse -3122 [4332] 22 2.34584924126e-05
# >  Recurse -3122 [4332] 3312 2.34584924126e-05
# ------>  Recurse -3122 [4332, 3312] -11 1.21108101563e-05
# ------>  Recurse -3122 [4332, 3312] 11 1.21108101563e-05
# ------>  Recurse -3122 [4332, 3312] 22 1.21108101563e-05
# ------>  Recurse -3122 [4332, 3312] 3112 1.21108101563e-05
# ------------>  Recurse -3122 [4332, 3312, 3112] 11 1.56093879205e-09
# >  Recurse -3122 [4332] 3322 2.34584924126e-05
# ------>  Recurse -3122 [4332, 3322] -11 1.76065670466e-05
# ------>  Recurse -3122 [4332, 3322] 11 1.76065670466e-05
# ------>  Recurse -3122 [4332, 3322] 22 1.76065670466e-05
# convert_to_compact::follow_chained_decay():  start recursion with -3122 [10421] 0.017212879145
# >  Recurse -3122 [10421] -11 0.017212879145
# >  Recurse -3122 [10421] 11 0.017212879145
# >  Recurse -3122 [10421] 22 0.017212879145
# convert_to_compact::follow_chained_decay():  start recursion with -2212 [-10421] 0.0185703958113
# >  Recurse -2212 [-10421] -11 0.0185703958113
# >  Recurse -2212 [-10421] 11 0.0185703958113
# >  Recurse -2212 [-10421] 22 0.0185703958113
# convert_to_compact::follow_chained_decay():  start recursion with -2212 [-4332] 2.78081744541e-05
# >  Recurse -2212 [-4332] -3322 2.78081744541e-05
# ------>  Recurse -2212 [-4332, -3322] -11 2.08824634414e-05
# ------>  Recurse -2212 [-4332, -3322] 11 2.08824634414e-05
# ------>  Recurse -2212 [-4332, -3322] 22 2.08824634414e-05
# >  Recurse -2212 [-4332] -3312 2.78081744541e-05
# ------>  Recurse -2212 [-4332, -3312] -3112 1.43643088495e-05
# ------------>  Recurse -2212 [-4332, -3312, -3112] -11 1.86963613408e-09
# ------>  Recurse -2212 [-4332, -3312] -11 1.43643088495e-05
# ------>  Recurse -2212 [-4332, -3312] 11 1.43643088495e-05
# ------>  Recurse -2212 [-4332, -3312] 22 1.43643088495e-05
# >  Recurse -2212 [-4332] -11 2.78081744541e-05
# >  Recurse -2212 [-4332] 11 2.78081744541e-05
# >  Recurse -2212 [-4332] 22 2.78081744541e-05
# convert_to_compact::follow_chained_decay():  start recursion with -2212 [-4324] 2.05365069902e-05
# >  Recurse -2212 [-4324] -4232 2.05365069902e-05
# ------>  Recurse -2212 [-4324, -4232] -3322 2.04859399372e-05
# ------------>  Recurse -2212 [-4324, -4232, -3322] -11 1.69583123231e-05
# ------------>  Recurse -2212 [-4324, -4232, -3322] 11 1.69583123231e-05
# ------------>  Recurse -2212 [-4324, -4232, -3322] 22 1.69583123231e-05
# ------>  Recurse -2212 [-4324, -4232] -3312 2.04859399372e-05
# ------------>  Recurse -2212 [-4324, -4232, -3312] -3112 2.96434873811e-07
# ------------------>  Recurse -2212 [-4324, -4232, -3312, -3112] -11 3.86874916621e-11
# ------------>  Recurse -2212 [-4324, -4232, -3312] -11 2.96434873811e-07
# ------------>  Recurse -2212 [-4324, -4232, -3312] 11 2.96434873811e-07
# ------------>  Recurse -2212 [-4324, -4232, -3312] 22 2.96434873811e-07
# ------>  Recurse -2212 [-4324, -4232] -11 2.04859399372e-05
# ------>  Recurse -2212 [-4324, -4232] 11 2.04859399372e-05
# ------>  Recurse -2212 [-4324, -4232] 22 2.04859399372e-05
# >  Recurse -2212 [-4324] -11 2.05365069902e-05
# >  Recurse -2212 [-4324] 11 2.05365069902e-05
# >  Recurse -2212 [-4324] 22 2.05365069902e-05
# convert_to_compact::follow_chained_decay():  start recursion with -2212 [-4314] 2.24119144568e-05
# >  Recurse -2212 [-4314] -4132 2.24119144568e-05
# ------>  Recurse -2212 [-4314, -4132] -3322 2.22415313517e-05
# ------------>  Recurse -2212 [-4314, -4132, -3322] -11 2.59661103148e-06
# ------------>  Recurse -2212 [-4314, -4132, -3322] 11 2.59661103148e-06
# ------------>  Recurse -2212 [-4314, -4132, -3322] 22 2.59661103148e-06
# ------>  Recurse -2212 [-4314, -4132] -3312 2.22415313517e-05
# ------------>  Recurse -2212 [-4314, -4132, -3312] -3112 1.26832492944e-05
# ------------------>  Recurse -2212 [-4314, -4132, -3312, -3112] -11 1.65156247483e-09
# ------------>  Recurse -2212 [-4314, -4132, -3312] -11 1.26832492944e-05
# ------------>  Recurse -2212 [-4314, -4132, -3312] 11 1.26832492944e-05
# ------------>  Recurse -2212 [-4314, -4132, -3312] 22 1.26832492944e-05
# ------>  Recurse -2212 [-4314, -4132] -3112 2.22415313517e-05
# ------------>  Recurse -2212 [-4314, -4132, -3112] -11 1.20337290679e-06
# ------>  Recurse -2212 [-4314, -4132] -11 2.22415313517e-05
# ------>  Recurse -2212 [-4314, -4132] 11 2.22415313517e-05
# ------>  Recurse -2212 [-4314, -4132] 22 2.22415313517e-05
# >  Recurse -2212 [-4314] -11 2.24119144568e-05
# >  Recurse -2212 [-4314] 11 2.24119144568e-05
# >  Recurse -2212 [-4314] 22 2.24119144568e-05
# convert_to_compact::follow_chained_decay():  start recursion with -2212 [-4232] 0.000631511545362
# >  Recurse -2212 [-4232] -3322 0.000631511545362
# ------>  Recurse -2212 [-4232, -3322] -11 0.000516185058155
# ------>  Recurse -2212 [-4232, -3322] 11 0.000516185058155
# ------>  Recurse -2212 [-4232, -3322] 22 0.000516185058155
# >  Recurse -2212 [-4232] -3312 0.000631511545362
# ------>  Recurse -2212 [-4232, -3312] -3112 9.0352086968e-06
# ------------>  Recurse -2212 [-4232, -3312, -3112] -11 1.17417292848e-09
# ------>  Recurse -2212 [-4232, -3312] -11 9.0352086968e-06
# ------>  Recurse -2212 [-4232, -3312] 11 9.0352086968e-06
# ------>  Recurse -2212 [-4232, -3312] 22 9.0352086968e-06
# >  Recurse -2212 [-4232] -11 0.000631511545362
# >  Recurse -2212 [-4232] 11 0.000631511545362
# ...
# ------>  Recurse 3122 [3334, 3312] 3112 0.000249222660582
# ------------>  Recurse 3122 [3334, 3312, 3112] 11 3.17026016573e-08
# >  Recurse 3122 [3334] 3322 0.00251842035625
# ------>  Recurse 3122 [3334, 3322] -11 0.000700315921428
# ------>  Recurse 3122 [3334, 3322] 11 0.000700315921428
# ------>  Recurse 3122 [3334, 3322] 22 0.000700315921428
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4112] 0.00147017188143
# >  Recurse 3122 [4112] 4122 0.00147017188143
# ------>  Recurse 3122 [4112, 4122] -11 0.00138294414668
# ------>  Recurse 3122 [4112, 4122] 11 0.00138294414668
# ------>  Recurse 3122 [4112, 4122] 22 0.00138294414668
# ------>  Recurse 3122 [4112, 4122] 3112 0.00138294414668
# ------------>  Recurse 3122 [4112, 4122, 3112] 11 9.921883386e-06
# ------>  Recurse 3122 [4112, 4122] 3312 0.00138294414668
# ------------>  Recurse 3122 [4112, 4122, 3312] -11 1.42899490544e-05
# ------------>  Recurse 3122 [4112, 4122, 3312] 11 1.42899490544e-05
# ------------>  Recurse 3122 [4112, 4122, 3312] 22 1.42899490544e-05
# ------------>  Recurse 3122 [4112, 4122, 3312] 3112 1.42899490544e-05
# ------------------>  Recurse 3122 [4112, 4122, 3312, 3112] 11 1.80299088573e-09
# ------>  Recurse 3122 [4112, 4122] 3322 0.00138294414668
# ------------>  Recurse 3122 [4112, 4122, 3322] -11 3.96351903926e-05
# ------------>  Recurse 3122 [4112, 4122, 3322] 11 3.96351903926e-05
# ------------>  Recurse 3122 [4112, 4122, 3322] 22 3.96351903926e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4114] 0.000322732430188
# >  Recurse 3122 [4114] 4122 0.000322732430188
# ------>  Recurse 3122 [4114, 4122] -11 0.00030696875291
# ------>  Recurse 3122 [4114, 4122] 11 0.00030696875291
# ------>  Recurse 3122 [4114, 4122] 22 0.00030696875291
# ------>  Recurse 3122 [4114, 4122] 3112 0.00030696875291
# ------------>  Recurse 3122 [4114, 4122, 3112] 11 2.19991992291e-06
# ------>  Recurse 3122 [4114, 4122] 3312 0.00030696875291
# ------------>  Recurse 3122 [4114, 4122, 3312] -11 3.16469007205e-06
# ------------>  Recurse 3122 [4114, 4122, 3312] 11 3.16469007205e-06
# ------------>  Recurse 3122 [4114, 4122, 3312] 22 3.16469007205e-06
# ------------>  Recurse 3122 [4114, 4122, 3312] 3112 3.16469007205e-06
# ------------------>  Recurse 3122 [4114, 4122, 3312, 3112] 11 3.99591670354e-10
# ------>  Recurse 3122 [4114, 4122] 3322 0.00030696875291
# ------------>  Recurse 3122 [4114, 4122, 3322] -11 8.78030723571e-06
# ------------>  Recurse 3122 [4114, 4122, 3322] 11 8.78030723571e-06
# ------------>  Recurse 3122 [4114, 4122, 3322] 22 8.78030723571e-06
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4122] 0.00561201621433
# >  Recurse 3122 [4122] -11 0.00561201621433
# >  Recurse 3122 [4122] 11 0.00561201621433
# >  Recurse 3122 [4122] 22 0.00561201621433
# >  Recurse 3122 [4122] 3112 0.00561201621433
# ------>  Recurse 3122 [4122, 3112] 11 3.92362983542e-05
# >  Recurse 3122 [4122] 3312 0.00561201621433
# ------>  Recurse 3122 [4122, 3312] -11 5.64603916327e-05
# ------>  Recurse 3122 [4122, 3312] 11 5.64603916327e-05
# ------>  Recurse 3122 [4122, 3312] 22 5.64603916327e-05
# ------>  Recurse 3122 [4122, 3312] 3112 5.64603916327e-05
# ------------>  Recurse 3122 [4122, 3312, 3112] 11 7.00683662992e-09
# >  Recurse 3122 [4122] 3322 0.00561201621433
# ------>  Recurse 3122 [4122, 3322] -11 0.000156587572363
# ------>  Recurse 3122 [4122, 3322] 11 0.000156587572363
# ------>  Recurse 3122 [4122, 3322] 22 0.000156587572363
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4132] 0.000687630279251
# >  Recurse 3122 [4132] -11 0.000687630279251
# >  Recurse 3122 [4132] 11 0.000687630279251
# >  Recurse 3122 [4132] 22 0.000687630279251
# >  Recurse 3122 [4132] 3112 0.000687630279251
# ------>  Recurse 3122 [4132, 3112] 11 3.69237531089e-05
# >  Recurse 3122 [4132] 3312 0.000687630279251
# ------>  Recurse 3122 [4132, 3312] -11 0.000388927189462
# ------>  Recurse 3122 [4132, 3312] 11 0.000388927189462
# ------>  Recurse 3122 [4132, 3312] 22 0.000388927189462
# ------>  Recurse 3122 [4132, 3312] 3112 0.000388927189462
# ------------>  Recurse 3122 [4132, 3312, 3112] 11 4.99548544457e-08
# >  Recurse 3122 [4132] 3322 0.000687630279251
# ------>  Recurse 3122 [4132, 3322] -11 7.96830023959e-05
# ------>  Recurse 3122 [4132, 3322] 11 7.96830023959e-05
# ------>  Recurse 3122 [4132, 3322] 22 7.96830023959e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4212] 0.00153619250408
# >  Recurse 3122 [4212] -11 0.00153619250408
# >  Recurse 3122 [4212] 11 0.00153619250408
# >  Recurse 3122 [4212] 22 0.00153619250408
# >  Recurse 3122 [4212] 4122 0.00153619250408
# ------>  Recurse 3122 [4212, 4122] -11 0.00143835414454
# ------>  Recurse 3122 [4212, 4122] 11 0.00143835414454
# ------>  Recurse 3122 [4212, 4122] 22 0.00143835414454
# ------>  Recurse 3122 [4212, 4122] 3112 0.00143835414454
# ------------>  Recurse 3122 [4212, 4122, 3112] 11 1.02881816796e-05
# ------>  Recurse 3122 [4212, 4122] 3312 0.00143835414454
# ------------>  Recurse 3122 [4212, 4122, 3312] -11 1.48181257967e-05
# ------------>  Recurse 3122 [4212, 4122, 3312] 11 1.48181257967e-05
# ------------>  Recurse 3122 [4212, 4122, 3312] 22 1.48181257967e-05
# ------------>  Recurse 3122 [4212, 4122, 3312] 3112 1.48181257967e-05
# ------------------>  Recurse 3122 [4212, 4122, 3312, 3112] 11 1.86781634408e-09
# ------>  Recurse 3122 [4212, 4122] 3322 0.00143835414454
# ------------>  Recurse 3122 [4212, 4122, 3322] -11 4.10981583751e-05
# ------------>  Recurse 3122 [4212, 4122, 3322] 11 4.10981583751e-05
# ------------>  Recurse 3122 [4212, 4122, 3322] 22 4.10981583751e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4214] 0.000340260450172
# >  Recurse 3122 [4214] -11 0.000340260450172
# >  Recurse 3122 [4214] 11 0.000340260450172
# >  Recurse 3122 [4214] 22 0.000340260450172
# >  Recurse 3122 [4214] 4122 0.000340260450172
# ------>  Recurse 3122 [4214, 4122] -11 0.000322877052268
# ------>  Recurse 3122 [4214, 4122] 11 0.000322877052268
# ------>  Recurse 3122 [4214, 4122] 22 0.000322877052268
# ------>  Recurse 3122 [4214, 4122] 3112 0.000322877052268
# ------------>  Recurse 3122 [4214, 4122, 3112] 11 2.30496708935e-06
# ------>  Recurse 3122 [4214, 4122] 3312 0.000322877052268
# ------------>  Recurse 3122 [4214, 4122, 3312] -11 3.31492883249e-06
# ------------>  Recurse 3122 [4214, 4122, 3312] 11 3.31492883249e-06
# ------------>  Recurse 3122 [4214, 4122, 3312] 22 3.31492883249e-06
# ------------>  Recurse 3122 [4214, 4122, 3312] 3112 3.31492883249e-06
# ------------------>  Recurse 3122 [4214, 4122, 3312, 3112] 11 4.18154137836e-10
# ------>  Recurse 3122 [4214, 4122] 3322 0.000322877052268
# ------------>  Recurse 3122 [4214, 4122, 3322] -11 9.19744261489e-06
# ------------>  Recurse 3122 [4214, 4122, 3322] 11 9.19744261489e-06
# ------------>  Recurse 3122 [4214, 4122, 3322] 22 9.19744261489e-06
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4222] 0.00172997869255
# >  Recurse 3122 [4222] 4122 0.00172997869255
# ------>  Recurse 3122 [4222, 4122] -11 0.00161059403319
# ------>  Recurse 3122 [4222, 4122] 11 0.00161059403319
# ------>  Recurse 3122 [4222, 4122] 22 0.00161059403319
# ------>  Recurse 3122 [4222, 4122] 3112 0.00161059403319
# ------------>  Recurse 3122 [4222, 4122, 3112] 11 1.14442420898e-05
# ------>  Recurse 3122 [4222, 4122] 3312 0.00161059403319
# ------------>  Recurse 3122 [4222, 4122, 3312] -11 1.64643716151e-05
# ------------>  Recurse 3122 [4222, 4122, 3312] 11 1.64643716151e-05
# ------------>  Recurse 3122 [4222, 4122, 3312] 22 1.64643716151e-05
# ------------>  Recurse 3122 [4222, 4122, 3312] 3112 1.64643716151e-05
# ------------------>  Recurse 3122 [4222, 4122, 3312, 3112] 11 2.07333667227e-09
# ------>  Recurse 3122 [4222, 4122] 3322 0.00161059403319
# ------------>  Recurse 3122 [4222, 4122, 3322] -11 4.56794721604e-05
# ------------>  Recurse 3122 [4222, 4122, 3322] 11 4.56794721604e-05
# ------------>  Recurse 3122 [4222, 4122, 3322] 22 4.56794721604e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4224] 0.000408080201661
# >  Recurse 3122 [4224] 4122 0.000408080201661
# ------>  Recurse 3122 [4224, 4122] -11 0.000384147852893
# ------>  Recurse 3122 [4224, 4122] 11 0.000384147852893
# ------>  Recurse 3122 [4224, 4122] 22 0.000384147852893
# ------>  Recurse 3122 [4224, 4122] 3112 0.000384147852893
# ------------>  Recurse 3122 [4224, 4122, 3112] 11 2.71713769912e-06
# ------>  Recurse 3122 [4224, 4122] 3312 0.000384147852893
# ------------>  Recurse 3122 [4224, 4122, 3312] -11 3.90481079267e-06
# ------------>  Recurse 3122 [4224, 4122, 3312] 11 3.90481079267e-06
# ------------>  Recurse 3122 [4224, 4122, 3312] 22 3.90481079267e-06
# ------------>  Recurse 3122 [4224, 4122, 3312] 3112 3.90481079267e-06
# ------------------>  Recurse 3122 [4224, 4122, 3312, 3112] 11 4.91521885741e-10
# ------>  Recurse 3122 [4224, 4122] 3322 0.000384147852893
# ------------>  Recurse 3122 [4224, 4122, 3322] -11 1.08358646781e-05
# ------------>  Recurse 3122 [4224, 4122, 3322] 11 1.08358646781e-05
# ------------>  Recurse 3122 [4224, 4122, 3322] 22 1.08358646781e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4232] 0.000695271854051
# >  Recurse 3122 [4232] -11 0.000695271854051
# >  Recurse 3122 [4232] 11 0.000695271854051
# >  Recurse 3122 [4232] 22 0.000695271854051
# >  Recurse 3122 [4232] 3312 0.000695271854051
# ------>  Recurse 3122 [4232, 3312] -11 9.84813111346e-06
# ------>  Recurse 3122 [4232, 3312] 11 9.84813111346e-06
# ------>  Recurse 3122 [4232, 3312] 22 9.84813111346e-06
# ------>  Recurse 3122 [4232, 3312] 3112 9.84813111346e-06
# ------------>  Recurse 3122 [4232, 3312, 3112] 11 1.26390848147e-09
# >  Recurse 3122 [4232] 3322 0.000695271854051
# ------>  Recurse 3122 [4232, 3322] -11 0.00056447220501
# ------>  Recurse 3122 [4232, 3322] 11 0.00056447220501
# ------>  Recurse 3122 [4232, 3322] 22 0.00056447220501
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4314] 2.99793304868e-05
# >  Recurse 3122 [4314] -11 2.99793304868e-05
# >  Recurse 3122 [4314] 11 2.99793304868e-05
# >  Recurse 3122 [4314] 22 2.99793304868e-05
# >  Recurse 3122 [4314] 4132 2.99793304868e-05
# ------>  Recurse 3122 [4314, 4132] -11 2.96240350812e-05
# ------>  Recurse 3122 [4314, 4132] 11 2.96240350812e-05
# ------>  Recurse 3122 [4314, 4132] 22 2.96240350812e-05
# ------>  Recurse 3122 [4314, 4132] 3112 2.96240350812e-05
# ------------>  Recurse 3122 [4314, 4132, 3112] 11 1.58444830372e-06
# ------>  Recurse 3122 [4314, 4132] 3312 2.96240350812e-05
# ------------>  Recurse 3122 [4314, 4132, 3312] -11 1.66828951666e-05
# ------------>  Recurse 3122 [4314, 4132, 3312] 11 1.66828951666e-05
# ------------>  Recurse 3122 [4314, 4132, 3312] 22 1.66828951666e-05
# ------------>  Recurse 3122 [4314, 4132, 3312] 3112 1.66828951666e-05
# ------------------>  Recurse 3122 [4314, 4132, 3312, 3112] 11 2.13832386286e-09
# ------>  Recurse 3122 [4314, 4132] 3322 2.96240350812e-05
# ------------>  Recurse 3122 [4314, 4132, 3322] -11 3.42043793968e-06
# ------------>  Recurse 3122 [4314, 4132, 3322] 11 3.42043793968e-06
# ------------>  Recurse 3122 [4314, 4132, 3322] 22 3.42043793968e-06
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4324] 3.07570515225e-05
# >  Recurse 3122 [4324] -11 3.07570515225e-05
# >  Recurse 3122 [4324] 11 3.07570515225e-05
# >  Recurse 3122 [4324] 22 3.07570515225e-05
# >  Recurse 3122 [4324] 4232 3.07570515225e-05
# ------>  Recurse 3122 [4324, 4232] -11 3.05222000539e-05
# ------>  Recurse 3122 [4324, 4232] 11 3.05222000539e-05
# ------>  Recurse 3122 [4324, 4232] 22 3.05222000539e-05
# ------>  Recurse 3122 [4324, 4232] 3312 3.05222000539e-05
# ------------>  Recurse 3122 [4324, 4232, 3312] -11 4.31561477275e-07
# ------------>  Recurse 3122 [4324, 4232, 3312] 11 4.31561477275e-07
# ------------>  Recurse 3122 [4324, 4232, 3312] 22 4.31561477275e-07
# ------------>  Recurse 3122 [4324, 4232, 3312] 3112 4.31561477275e-07
# ------------------>  Recurse 3122 [4324, 4232, 3312, 3112] 11 5.5318216593e-11
# ------>  Recurse 3122 [4324, 4232] 3322 3.05222000539e-05
# ------------>  Recurse 3122 [4324, 4232, 3322] -11 2.47288881622e-05
# ------------>  Recurse 3122 [4324, 4232, 3322] 11 2.47288881622e-05
# ------------>  Recurse 3122 [4324, 4232, 3322] 22 2.47288881622e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [4332] 2.67101033813e-05
# >  Recurse 3122 [4332] -11 2.67101033813e-05
# >  Recurse 3122 [4332] 11 2.67101033813e-05
# >  Recurse 3122 [4332] 22 2.67101033813e-05
# >  Recurse 3122 [4332] 3312 2.67101033813e-05
# ------>  Recurse 3122 [4332, 3312] -11 1.3824796734e-05
# ------>  Recurse 3122 [4332, 3312] 11 1.3824796734e-05
# ------>  Recurse 3122 [4332, 3312] 22 1.3824796734e-05
# ------>  Recurse 3122 [4332, 3312] 3112 1.3824796734e-05
# ------------>  Recurse 3122 [4332, 3312, 3112] 11 1.78235692936e-09
# >  Recurse 3122 [4332] 3322 2.67101033813e-05
# ------>  Recurse 3122 [4332, 3322] -11 2.00995877015e-05
# ------>  Recurse 3122 [4332, 3322] 11 2.00995877015e-05
# ------>  Recurse 3122 [4332, 3322] 22 2.00995877015e-05
# convert_to_compact::follow_chained_decay():  start recursion with 3122 [10421] 0.0183732637759
# >  Recurse 3122 [10421] -11 0.0183732637759
# >  Recurse 3122 [10421] 11 0.0183732637759
# >  Recurse 3122 [10421] 22 0.0183732637759
# extend_to_low_energies(): transition_idx=15, transition_energy=87.4947104666
# ('InteractionYields::_decompress():: Decompressing ', '/Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/SIBYLL23_yields_compact_ledpm.bz2')
# InteractionYields::_gen_index(): entering..
# ('InteractionYields::_decompress():: Saving to ', '/Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/SIBYLL23_yields_compact_ledpm.ppd')
# DecayYields:_load():: Loading file /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/decays_v1_compact.ppd
# Decompressing /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/decays_v1_compact.bz2
# Saving to /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/decays_v1_compact.ppd
# Decompressing /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/crosssections.bz2
# Saving to /Users/mhuber/AtmosphericMuons_Anatoli/MCEq/data/crosssections.ppd
# MCEqRun::_gen_list_of_particles():Generating particle list.
# MCEqRun::_init_alias_tables():Initializing links to alias IDs.
#
# Hadrons and stable particles:
#
# "p", "p-bar", "n-bar", "n"
#
# Mixed:
#
# "pi-", "pi+", "K0L", "K-", "K+", "Lambda0", "Lambda0-bar", "K0S",
# "D+", "D-", "Ds+", "Ds-", "D0", "D0-bar"
#
# Resonances:
#
#
#
# Leptons:
#
# "e-", "nue", "numu", "nutau", "antinutau", "antinumu", "antinue", "e+",
# "mu-", "mu+"
#
# Aliases:
# "obs_numu", "obs_nutau", "gamma", "pr_antinutau", "pr_antinumu", "pr_antinue", "obs_antinue", "k_nue",
# "k_numu", "k_nutau", "pi_antinutau", "pi_antinue", "pi_antinumu", "pi_nue", "pi_numu", "pi_nutau",
# "k_antinutau", "k_antinumu", "k_antinue", "obs_nue", "pr_nue", "pr_numu", "pr_nutau", "obs_antinutau",
# "obs_antinumu", "k_mu-", "obs_mu-", "pr_mu+", "pi_mu+", "pi_mu-", "k_mu+", "pr_mu-",
# "obs_mu+"
#
# Total number of species: 61
# MCEqRun::set_interaction_model():  SIBYLL23
# InteractionYields:set_interaction_model():: Model SIBYLL23 already loaded.
# InteractionYields:set_interaction_model():: Model SIBYLL23 already loaded.
# MCEqRun::_init_default_matrices():Start filling matrices. Skip_D_matrix = False
# MCEqRun_fill_matrices(): Particle production by 3122 explicitly disabled
# MCEqRun_fill_matrices(): Particle production by -3122 explicitly disabled
# MCEqRun::_convert_to_sparse():Converting to sparse (CSR) matrix format.
# C Matrix info:
#     density    : 3.41%
#     shape      : 5368 x 5368
#     nnz        : 981415
#     sum        : 590346233162.0
# D Matrix info:
#     density    : 1.11%
#     shape      : 5368 x 5368
#     nnz        : 318463
#     sum        : 0.20730586438
# MCEqRun::_init_default_matrices():Done filling matrices.
# MCEqRun::set_density_model():  CORSIKA ('BK_USStd', None)
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.03s
# MCEqRun::_gen_list_of_particles():Generating particle list.
# MCEqRun::set_primary_model():  Thunman None

# %% [markdown]
# Solve and store results
# ----------------------

# %%
#Define equidistant grid in cos(theta)
angles = np.arccos(np.linspace(1,0,11))*180./np.pi

#Power of energy to scale the flux
mag = 3

#obtain energy grid (nver changes) of the solution for the x-axis of the plots
e_grid = mceq_run.e_grid

p_spectrum_flux = []

#Initialize empty grid
for  pmcount, pmodel in enumerate([(pm.HillasGaisser2012,'H3a'),
                                   (pm.HillasGaisser2012,'H4a'),
                                   (pm.GaisserStanevTilav,'3-gen'),
                                   (pm.GaisserStanevTilav,'4-gen')]):
    
    mceq_run.set_primary_model(*pmodel)
    
    flux = {}
    for frac in ['mu_conv','mu_pr','mu_total',
                 'numu_conv','numu_pr','numu_total',
                 'nue_conv','nue_pr','nue_total','nutau_pr']:
        flux[frac] = np.zeros_like(e_grid)
        

    #Sum fluxes, calculated for different angles
    for theta in angles:
        mceq_run.set_theta_deg(theta)
        mceq_run.solve()
        #_conv means conventional (mostly pions and kaons)
        flux['mu_conv'] += (mceq_run.get_solution('conv_mu+', mag)
                           + mceq_run.get_solution('conv_mu-', mag))

        # _pr means prompt (the mother of the muon had a critical energy
        # higher than a D meson. Includes all charm and direct resonance
        # contribution)
        flux['mu_pr'] += (mceq_run.get_solution('pr_mu+', mag)
                         + mceq_run.get_solution('pr_mu-', mag))

        # total means conventional + prompt
        flux['mu_total'] += (mceq_run.get_solution('total_mu+', mag)
                            + mceq_run.get_solution('total_mu-', mag))

        # same meaning of prefixes for muon neutrinos as for muons
        flux['numu_conv'] += (mceq_run.get_solution('conv_numu', mag)
                             + mceq_run.get_solution('conv_antinumu', mag))

        flux['numu_pr'] += (mceq_run.get_solution('pr_numu', mag)
                           + mceq_run.get_solution('pr_antinumu', mag))

        flux['numu_total'] += (mceq_run.get_solution('total_numu', mag)
                              + mceq_run.get_solution('total_antinumu', mag))

        # same meaning of prefixes for electron neutrinos as for muons
        flux['nue_conv'] += (mceq_run.get_solution('conv_nue', mag)
                            + mceq_run.get_solution('conv_antinue', mag))

        flux['nue_pr'] += (mceq_run.get_solution('pr_nue', mag)
                          + mceq_run.get_solution('pr_antinue', mag))

        flux['nue_total'] += (mceq_run.get_solution('total_nue', mag)
                             + mceq_run.get_solution('total_antinue', mag))


        # since there are no conventional tau neutrinos, prompt=total
        flux['nutau_pr'] += (mceq_run.get_solution('total_nutau', mag)
                            + mceq_run.get_solution('total_antinutau', mag))

    #average the results
    for frac in ['mu_conv','mu_pr','mu_total',
                 'numu_conv','numu_pr','numu_total',
                 'nue_conv','nue_pr','nue_total','nutau_pr']:
        flux[frac] = flux[frac]/float(len(angles))
        
    p_spectrum_flux.append((flux,mceq_run.pmodel.sname,mceq_run.pmodel.name))
# Out:
# MCEqRun::set_primary_model():  HillasGaisser2012 H3a
# MCEqRun::set_theta_deg():  0.0
# Theta selection correponds to cached value, skipping calc.
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.21ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.485877037048 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.10ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.434469938278 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.15ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.506053924561 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.60ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.802639007568 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.62ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.939327955246 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.09ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.745390176773 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.03ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.865391969681 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.78ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.92656993866 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.05ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.55726909637 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.32ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.9727730751 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.50ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 5.59331703186 sec
# MCEqRun::set_primary_model():  HillasGaisser2012 H4a
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.07ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.380145072937 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.06ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.418771028519 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.07ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.47101688385 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.36ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.680459022522 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.64ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.948487997055 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.77ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.21233010292 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.35ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.13441991806 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   2.02ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.18577599525 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.07ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.58226799965 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.32ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.96207904816 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.88ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 7.00691199303 sec
# MCEqRun::set_primary_model():  GaisserStanevTilav 3-gen
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.26ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.448547840118 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.19ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.466399908066 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.11ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.487794160843 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.99ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.996464967728 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   2.14ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.23746609688 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.38ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.947552919388 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.43ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.20100283623 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.08ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.1689748764 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.02ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.51826310158 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.14ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.55368995667 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   1.85ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 6.91223096848 sec
# MCEqRun::set_primary_model():  GaisserStanevTilav 4-gen
# MCEqRun::set_theta_deg():  0.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 0.0 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1033.80949621
# MCEqRun::_forward_euler(): Solver will perform 355 integration steps.
# Performance:   1.93ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.685202121735 sec
# MCEqRun::set_theta_deg():  25.8419327632
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 25.8419327632 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1148.36904804
# MCEqRun::_forward_euler(): Solver will perform 393 integration steps.
# Performance:   1.27ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.499924182892 sec
# MCEqRun::set_theta_deg():  36.8698976458
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 36.8698976458 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1291.4328393
# MCEqRun::_forward_euler(): Solver will perform 440 integration steps.
# Performance:   1.43ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.628663063049 sec
# MCEqRun::set_theta_deg():  45.5729959992
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 45.5729959992 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1475.12083987
# MCEqRun::_forward_euler(): Solver will perform 500 integration steps.
# Performance:   1.86ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.929785966873 sec
# MCEqRun::set_theta_deg():  53.1301023542
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 53.1301023542 degrees.
# .. took 0.04s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 1719.53731755
# MCEqRun::_forward_euler(): Solver will perform 579 integration steps.
# Performance:   1.51ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 0.87412405014 sec
# MCEqRun::set_theta_deg():  60.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 60.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2060.60278351
# MCEqRun::_forward_euler(): Solver will perform 686 integration steps.
# Performance:   1.59ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.08911514282 sec
# MCEqRun::set_theta_deg():  66.4218215218
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 66.4218215218 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 2569.28270085
# MCEqRun::_forward_euler(): Solver will perform 841 integration steps.
# Performance:   1.44ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.2120308876 sec
# MCEqRun::set_theta_deg():  72.5423968763
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 72.5423968763 degrees.
# .. took 0.05s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 3407.46234528
# MCEqRun::_forward_euler(): Solver will perform 1080 integration steps.
# Performance:   1.56ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 1.68650817871 sec
# MCEqRun::set_theta_deg():  78.4630409672
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 78.4630409672 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 5037.05170842
# MCEqRun::_forward_euler(): Solver will perform 1485 integration steps.
# Performance:   1.57ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.33690810204 sec
# MCEqRun::set_theta_deg():  84.2608295227
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 84.2608295227 degrees.
# .. took 0.03s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 9422.42525549
# MCEqRun::_forward_euler(): Solver will perform 2246 integration steps.
# Performance:   1.22ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 2.73183584213 sec
# MCEqRun::set_theta_deg():  90.0
# CorsikaAtmosphere::calculate_density_spline(): Calculating spline of rho(X) for zenith 90.0 degrees.
# .. took 0.02s
# MCEqRun::solve(): solver=euler and sparse=True
# MCEqRun::_calculate_integration_path(): X_surface = 36583.2539537
# MCEqRun::_forward_euler(): Solver will perform 3727 integration steps.
# Performance:   2.16ms/iteration
#
# MCEqRun::_forward_euler(): time elapsed during integration: 8.03526306152 sec

# %% [markdown]
# Plot with matplotlib
# --------------------

# %%
for pref, lab in [('numu_',r'\nu_\mu'), 
#                   ('mu_',r'\mu'), 
#                   ('nue_',r'\nu_e')
                 ]:
    plt.figure(figsize=(4.5, 3.5))
    for (flux, p_sname, p_name), col in zip(p_spectrum_flux,['k','r','g','b']):
        
        plt.loglog(e_grid, flux[pref + 'total'], color=col, ls='-', lw=2.5,
                  label=p_sname, alpha=0.4)
        plt.loglog(e_grid, flux[pref + 'conv'], color=col, ls='--', lw=1,
                   label='_nolabel_')
        plt.loglog(e_grid, flux[pref + 'pr'], color=col,ls='-', lw=1, 
                   label='_nolabel_')
    plt.xlim(50,1e9)
    plt.ylim(1e-6,1)
    plt.xlabel(r"$E_{{{0}}}$ [GeV]".format(lab))
    plt.ylabel(r"$\Phi_{" + lab + "}$ (E/GeV)$^{" + str(mag) +" }$" + 
               "(cm$^{2}$ s sr GeV)$^{-1}$")
    plt.legend(loc='upper right')
    plt.tight_layout()
    #save(pref + 'flux')

# %% [markdown]
# Save as in ASCII file for other types of processing
# ---------------------------------------------------

# %%
np.savetxt(open(os.path.join(desktop, 'my_flux_calculation.txt'),'w'),
zip(e_grid, 
    flux['mu_conv'],flux['mu_pr'],flux['mu_total'],
    flux['numu_conv'],flux['numu_pr'],flux['numu_total'],
    flux['nue_conv'],flux['nue_pr'],flux['nue_total'],
    flux['nutau_pr']),
fmt='%6.5E',
header=('lepton flux scaled with E**{0}. Order (E, mu_conv, mu_pr, mu_total, ' +
        'numu_conv, numu_pr, numu_total, nue_conv, nue_pr, nue_total, ' +
        'nutau_pr').format(mag)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2e26744ae1f8> in <module>()
# ----> 1 np.savetxt(open(os.path.join(desktop, 'my_flux_calculation.txt'),'w'),
#       2 zip(e_grid,
#       3     flux['mu_conv'],flux['mu_pr'],flux['mu_total'],
#       4     flux['numu_conv'],flux['numu_pr'],flux['numu_total'],
#       5     flux['nue_conv'],flux['nue_pr'],flux['nue_total'],
#
# NameError: name 'desktop' is not defined

# %%
egrid = mceq_run.e_grid
iam_str = mceq_run.iamodel_name
plotloc = os.path.join(os.path.expanduser("~"),'Google Drive/Plots/plots_new_sibyll/ICRC2015')

def make_naked(ax):
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.tick_left()
    
def save(plotname):
    plt.savefig(os.path.join(plotloc,plotname + '.pdf'))
    
def pickle_data(obj, fname):
    import cPickle as pickle
    pickle.dump(obj,open(os.path.join(plotloc,fname + '.pic'),'wb'),protocol=-1)

def unpickle_data(fname):
    import cPickle as pickle
    return pickle.load(open(os.path.join(plotloc,fname + '.pic'),'rb'))
